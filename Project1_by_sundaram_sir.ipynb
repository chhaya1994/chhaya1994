# %% [markdown]
# <a href="https://colab.research.google.com/github/chhaya1994/chhaya1994/blob/main/Project1_by_sundaram_sir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing necessary libraries

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
bank = pd.read_csv('C:/Users/singh/Downloads/Bank customers.csv')
bank.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
bank.shape  # there are 10127 details given.
            # 21 variables are there
# Out:
# (10127, 21)

# %%
bank.isnull().sum() #
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  int64
#  18  Total_Trans_Ct            10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 1.6+ MB

# %%
sns.set_theme(style='whitegrid')
sns.boxplot(bank['Customer_Age'])
plt.show()

# %%
bank.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
bank[['Gender','Credit_Limit']].groupby('Gender').agg(['mean','count'])
# Out:
#         Credit_Limit
#                 mean count
# Gender
# F        5023.854274  5358
# M       12685.674963  4769

# %%
# now we are checking who is doing more transaction male or female
bank[['Gender','Avg_Utilization_Ratio']].groupby('Gender').agg(['mean','count'])
# Out:
#        Avg_Utilization_Ratio
#                         mean count
# Gender
# F                   0.341957  5358
# M                   0.199548  4769

# %%
bank_cards = bank.groupby('Card_Category')  # Age will be mazor factor to  we enhance the credit limit
bank_cards['Customer_Age'].max()
# Out:
# Card_Category
# Blue        73
# Gold        63
# Platinum    56
# Silver      65
# Name: Customer_Age, dtype: int64

# %%
bank_cards = bank.groupby('Card_Category')
bank_cards['Customer_Age'].min()
# Out:
# Card_Category
# Blue        26
# Gold        29
# Platinum    39
# Silver      26
# Name: Customer_Age, dtype: int64

# %%
# bank cards average utilization
bank_cards['Avg_Utilization_Ratio'].mean()
# Out:
# Card_Category
# Blue        0.290859
# Gold        0.057103
# Platinum    0.043650
# Silver      0.057310
# Name: Avg_Utilization_Ratio, dtype: float64

# %%
bank_marital = bank.groupby('Marital_Status')

# %%
bank_marital ['Card_Category'].value_counts()
# Out:
# Marital_Status  Card_Category
# Divorced        Blue              696
#                 Silver             46
#                 Gold                5
#                 Platinum            1
# Married         Blue             4433
#                 Silver            206
#                 Gold               41
#                 Platinum            7
# Single          Blue             3624
#                 Silver            251
#                 Gold               58
#                 Platinum           10
# Unknown         Blue              683
#                 Silver             52
#                 Gold               12
#                 Platinum            2
# Name: count, dtype: int64

# %%
# lets move forward we need to check categorical data in dataset
bank.head(2)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
#
# [2 rows x 21 columns]

# %%
bank['Attrition_Flag'].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
bank['Gender'].value_counts()
# Out:
# Gender
# F    5358
# M    4769
# Name: count, dtype: int64

# %%
bank['Education_Level'].value_counts()
# Out:
# Education_Level
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: count, dtype: int64

# %%
bank['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: count, dtype: int64

# %%
bank['Card_Category'].value_counts()
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64

# %%
def ref1(x):       # we are going to do lable encoder becoz here are only two male and female
    if x=='M':
        return 1
    else:
        return 0
bank['Gender']=bank['Gender'].map(ref1)

# %%
bank['Gender'].value_counts()
# Out:
# Gender
# 0    5358
# 1    4769
# Name: count, dtype: int64

# %%
def ref2(x):
    if x == 'Existing Customer':
        return 1
    else:
        return 0
bank['Attrition_Flag']=bank['Attrition_Flag'].map(ref2)

# %%
bank['Attrition_Flag'].value_counts()
# Out:
# Attrition_Flag
# 1    8500
# 0    1627
# Name: count, dtype: int64

# %%
bank.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               1            45       1                3
# 1  818770008               1            49       0                5
# 2  713982108               1            51       1                3
# 3  769911858               1            40       0                4
# 4  709106358               1            40       1                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
# we are converting categorical data into numerical data
y = bank['Card_Category']
x = bank.copy()

# %%
x.head(2)
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               1            45       1                3
# 1  818770008               1            49       0                5
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
#
# [2 rows x 21 columns]

# %%
x['Income_Category'].value_counts()
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(feat):
    le = LabelEncoder()
    le.fit(feat)
    print(feat.name, le.classes_)
    return le.transform(feat)

# %%
x['Income_Category']=label_encoder(x['Income_Category'])
x.head(5)
# Out:
# Income_Category ['$120K +' '$40K - $60K' '$60K - $80K' '$80K - $120K' 'Less than $40K'
#  'Unknown']
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               1            45       1                3
# 1  818770008               1            49       0                5
# 2  713982108               1            51       1                3
# 3  769911858               1            40       0                4
# 4  709106358               1            40       1                3
#
#   Education_Level Marital_Status  Income_Category Card_Category  \
# 0     High School        Married                2          Blue
# 1        Graduate         Single                4          Blue
# 2        Graduate        Married                3          Blue
# 3     High School        Unknown                4          Blue
# 4      Uneducated        Married                2          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
x['Income_Category'].value_counts()
# Out:
# Income_Category
# 4    3561
# 1    1790
# 3    1535
# 2    1402
# 5    1112
# 0     727
# Name: count, dtype: int64

# %%
x['Education_Level']=label_encoder(x['Education_Level'])
x['Marital_Status']=label_encoder(x['Marital_Status'])
x.head(5)
# Out:
# Education_Level ['College' 'Doctorate' 'Graduate' 'High School' 'Post-Graduate'
#  'Uneducated' 'Unknown']
# Marital_Status ['Divorced' 'Married' 'Single' 'Unknown']
#    CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383               1            45       1                3
# 1  818770008               1            49       0                5
# 2  713982108               1            51       1                3
# 3  769911858               1            40       0                4
# 4  709106358               1            40       1                3
#
#    Education_Level  Marital_Status  Income_Category Card_Category  \
# 0                3               1                2          Blue
# 1                2               2                4          Blue
# 2                2               1                3          Blue
# 3                3               3                4          Blue
# 4                5               1                2          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
x= x.drop(['CLIENTNUM','Card_Category'],axis=1,errors='ignore')
x.shape
# Out:
# (10127, 19)

# %%
y.value_counts()
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64

# %%
y
# Out:
# 0          Blue
# 1          Blue
# 2          Blue
# 3          Blue
# 4          Blue
#           ...
# 10122      Blue
# 10123      Blue
# 10124      Blue
# 10125      Blue
# 10126    Silver
# Name: Card_Category, Length: 10127, dtype: object

# %%
y = bank[['Card_Category']]
y
# Out:
#       Card_Category
# 0              Blue
# 1              Blue
# 2              Blue
# 3              Blue
# 4              Blue
# ...             ...
# 10122          Blue
# 10123          Blue
# 10124          Blue
# 10125          Blue
# 10126        Silver
#
# [10127 rows x 1 columns]

# %%
y['Card_Category']=label_encoder(y['Card_Category'])
y.head(5)
# Out:
# Card_Category ['Blue' 'Gold' 'Platinum' 'Silver']
#    Card_Category
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
y['Card_Category'].value_counts()
# Out:
# Card_Category
# 0    9436
# 3     555
# 1     116
# 2      20
# Name: count, dtype: int64

# %%
x.describe()
# Out:
#        Attrition_Flag  Customer_Age        Gender  Dependent_count  \
# count    10127.000000  10127.000000  10127.000000     10127.000000
# mean         0.839340     46.325960      0.470919         2.346203
# std          0.367235      8.016814      0.499178         1.298908
# min          0.000000     26.000000      0.000000         0.000000
# 25%          1.000000     41.000000      0.000000         1.000000
# 50%          1.000000     46.000000      0.000000         2.000000
# 75%          1.000000     52.000000      1.000000         3.000000
# max          1.000000     73.000000      1.000000         5.000000
#
#        Education_Level  Marital_Status  Income_Category  Months_on_book  \
# count     10127.000000    10127.000000     10127.000000    10127.000000
# mean          3.096574        1.463415         2.863928       35.928409
# std           1.834812        0.737808         1.504700        7.986416
# min           0.000000        0.000000         0.000000       13.000000
# 25%           2.000000        1.000000         2.000000       31.000000
# 50%           3.000000        1.000000         3.000000       36.000000
# 75%           5.000000        2.000000         4.000000       40.000000
# max           6.000000        3.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %%
# we will treat for outlier
def boxplots(col):
    sns.boxplot(x[col])
    plt.show()

for i in list(x.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
# lets check the number of outlier per column
Q1=x.quantile(0.25)
Q3=x.quantile(0.75)

IQR = Q3-Q1
UL=Q3+1.5*IQR
LL=Q1-1.5*IQR

print (UL)
print()
print(LL)
# Out:
# Attrition_Flag                  1.000
# Customer_Age                   68.500
# Gender                          2.500
# Dependent_count                 6.000
# Education_Level                 9.500
# Marital_Status                  3.500
# Income_Category                 7.000
# Months_on_book                 53.500
# Total_Relationship_Count        8.000
# Months_Inactive_12_mon          4.500
# Contacts_Count_12_mon           4.500
# Credit_Limit                23836.250
# Total_Revolving_Bal          3921.500
# Avg_Open_To_Buy             22660.750
# Total_Amt_Chng_Q4_Q1            1.201
# Total_Trans_Amt              8619.250
# Total_Trans_Ct                135.000
# Total_Ct_Chng_Q4_Q1             1.172
# Avg_Utilization_Ratio           1.223
# dtype: float64
#
# Attrition_Flag                  1.000
# Customer_Age                   24.500
# Gender                         -1.500
# Dependent_count                -2.000
# Education_Level                -2.500
# Marital_Status                 -0.500
# Income_Category                -1.000
# Months_on_book                 17.500
# Total_Relationship_Count        0.000
# Months_Inactive_12_mon          0.500
# Contacts_Count_12_mon           0.500
# Credit_Limit               -10213.750
# Total_Revolving_Bal         -1778.500
# Avg_Open_To_Buy            -11477.250
# Total_Amt_Chng_Q4_Q1            0.289
# Total_Trans_Amt             -1722.750
# Total_Trans_Ct                 -9.000
# Total_Ct_Chng_Q4_Q1             0.228
# Avg_Utilization_Ratio          -0.697
# dtype: float64

# %%
((x>UL)|(x<LL)).sum()
# Out:
# Attrition_Flag              1627
# Customer_Age                   2
# Gender                         0
# Dependent_count                0
# Education_Level                0
# Marital_Status                 0
# Income_Category                0
# Months_on_book               386
# Total_Relationship_Count       0
# Months_Inactive_12_mon       331
# Contacts_Count_12_mon        629
# Credit_Limit                 984
# Total_Revolving_Bal            0
# Avg_Open_To_Buy              963
# Total_Amt_Chng_Q4_Q1         396
# Total_Trans_Amt              896
# Total_Trans_Ct                 2
# Total_Ct_Chng_Q4_Q1          394
# Avg_Utilization_Ratio          0
# dtype: int64

# %%
x[((x>UL)|(x<LL))] = np.NaN

# %%
plt.figure(figsize=(16,12))
sns.heatmap(x.isnull(),  cbar=False,cmap='rainbow',  yticklabels=False)
plt.show()

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=5)
x_impute=pd.DataFrame(imputer.fit_transform(x),columns=x.columns)
x_impute
# Out:
#        Attrition_Flag  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0                 1.0          45.0     1.0              3.0              3.0
# 1                 1.0          49.0     0.0              5.0              2.0
# 2                 1.0          51.0     1.0              3.0              2.0
# 3                 1.0          40.0     0.0              4.0              3.0
# 4                 1.0          40.0     1.0              3.0              5.0
# ...               ...           ...     ...              ...              ...
# 10122             1.0          50.0     1.0              2.0              2.0
# 10123             1.0          41.0     1.0              2.0              6.0
# 10124             1.0          44.0     0.0              1.0              3.0
# 10125             1.0          30.0     1.0              2.0              2.0
# 10126             1.0          43.0     0.0              2.0              2.0
#
#        Marital_Status  Income_Category  Months_on_book  \
# 0                 1.0              2.0            39.0
# 1                 2.0              4.0            44.0
# 2                 1.0              3.0            36.0
# 3                 3.0              4.0            34.0
# 4                 1.0              2.0            21.0
# ...               ...              ...             ...
# 10122             2.0              1.0            40.0
# 10123             0.0              1.0            25.0
# 10124             1.0              4.0            36.0
# 10125             3.0              1.0            36.0
# 10126             1.0              4.0            25.0
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                           5.0                     1.0
# 1                           6.0                     1.0
# 2                           4.0                     1.0
# 3                           3.0                     4.0
# 4                           5.0                     1.0
# ...                         ...                     ...
# 10122                       3.0                     2.0
# 10123                       4.0                     2.0
# 10124                       5.0                     3.0
# 10125                       4.0                     3.0
# 10126                       6.0                     2.0
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                        3.0       12691.0                777.0
# 1                        2.0        8256.0                864.0
# 2                        2.8        3418.0                  0.0
# 3                        1.0        3313.0               2517.0
# 4                        3.2        4716.0                  0.0
# ...                      ...           ...                  ...
# 10122                    3.0        4003.0               1851.0
# 10123                    3.0        4277.0               2186.0
# 10124                    4.0        5409.0                  0.0
# 10125                    3.0        5281.0                  0.0
# 10126                    4.0       10388.0               1961.0
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                0.7828           1144.0            42.0
# 1               7392.0                0.7648           1291.0            33.0
# 2               3418.0                0.7050           1887.0            20.0
# 3                796.0                0.8256           1171.0            20.0
# 4               4716.0                0.8498            816.0            28.0
# ...                ...                   ...              ...             ...
# 10122           2152.0                0.7030           4724.2           117.0
# 10123           2091.0                0.8040           5210.2            69.0
# 10124           5409.0                0.8190           3423.8            60.0
# 10125           5281.0                0.5350           8395.0            62.0
# 10126           8427.0                0.7030           3729.2            61.0
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                   0.8412                  0.061
# 1                   0.7442                  0.105
# 2                   0.5718                  0.000
# 3                   0.8286                  0.760
# 4                   0.8014                  0.000
# ...                    ...                    ...
# 10122               0.8570                  0.462
# 10123               0.6830                  0.511
# 10124               0.8180                  0.000
# 10125               0.7220                  0.000
# 10126               0.6490                  0.189
#
# [10127 rows x 19 columns]

# %%
x_impute.isnull().sum().sum()
# Out:
# 0

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x_impute),columns=x_impute.columns)
x_scaled
# Out:
#        Attrition_Flag  Customer_Age    Gender  Dependent_count  \
# 0                 0.0     -0.164953  1.059956         0.503368
# 1                 0.0      0.334481 -0.943436         2.043199
# 2                 0.0      0.584198  1.059956         0.503368
# 3                 0.0     -0.789247 -0.943436         1.273283
# 4                 0.0     -0.789247  1.059956         0.503368
# ...               ...           ...       ...              ...
# 10122             0.0      0.459340  1.059956        -0.266547
# 10123             0.0     -0.664388  1.059956        -0.266547
# 10124             0.0     -0.289812 -0.943436        -1.036462
# 10125             0.0     -2.037833  1.059956        -0.266547
# 10126             0.0     -0.414671 -0.943436        -0.266547
#
#        Education_Level  Marital_Status  Income_Category  Months_on_book  \
# 0            -0.052637       -0.628128        -0.574182        0.445726
# 1            -0.597678        0.727306         0.755053        1.162235
# 2            -0.597678       -0.628128         0.090436        0.015820
# 3            -0.052637        2.082739         0.755053       -0.270784
# 4             1.037447       -0.628128        -0.574182       -2.133708
# ...                ...             ...              ...             ...
# 10122        -0.597678        0.727306        -1.238799        0.589028
# 10123         1.582489       -1.983561        -1.238799       -1.560501
# 10124        -0.052637       -0.628128         0.755053        0.015820
# 10125        -0.597678        2.082739        -1.238799        0.015820
# 10126        -0.597678       -0.628128         0.755053       -1.560501
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# 0                      0.763943               -1.483108
# 1                      1.407306               -1.483108
# 2                      0.120579               -1.483108
# 3                     -0.522785                2.064343
# 4                      0.763943               -1.483108
# ...                         ...                     ...
# 10122                 -0.522785               -0.300624
# 10123                  0.120579               -0.300624
# 10124                  0.763943                0.881859
# 10125                  0.120579                0.881859
# 10126                  1.407306               -0.300624
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 0                   0.560289      1.221012            -0.473422
# 1                  -0.543612      0.361427            -0.366667
# 2                   0.339509     -0.576266            -1.426858
# 3                  -1.647513     -0.596617             1.661686
# 4                   0.781070     -0.324690            -1.426858
# ...                      ...           ...                  ...
# 10122               0.560289     -0.462882             0.844455
# 10123               0.560289     -0.409776             1.255524
# 10124               1.664191     -0.190373            -1.426858
# 10125               0.560289     -0.215182            -1.426858
# 10126               1.664191      0.774648             0.979433
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0             1.285984              0.272150        -1.436350       -0.974253
# 1             0.413906              0.161001        -1.354814       -1.358070
# 2            -0.352489             -0.208260        -1.024235       -1.912473
# 3            -0.858148              0.536438        -1.421374       -1.912473
# 4            -0.102167              0.685872        -1.618279       -1.571302
# ...                ...                   ...              ...             ...
# 10122        -0.596640             -0.220610         0.549455        2.224226
# 10123        -0.608404              0.403059         0.819021        0.177200
# 10124         0.031480              0.495683        -0.171829       -0.206618
# 10125         0.006794             -1.258001         2.585512       -0.121325
# 10126         0.613508             -0.220610        -0.002435       -0.163971
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                 0.837367              -0.775882
# 1                 0.282046              -0.616276
# 2                -0.704937              -0.997155
# 3                 0.765233               1.759686
# 4                 0.609514              -0.997155
# ...                    ...                    ...
# 10122             0.927821               0.678714
# 10123            -0.068321               0.856458
# 10124             0.704548              -0.997155
# 10125             0.154952              -0.997155
# 10126            -0.262970              -0.311572
#
# [10127 rows x 19 columns]

# %%
# split the data for the traning or testing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42,stratify=y)

# %%
# !pip install dtale

import dtale
dtale.show(bank)
# Out:
# Requirement already satisfied: dtale in d:\user\chhaya\lib\site-packages (3.14.1)
# Requirement already satisfied: dash-colorscales in d:\user\chhaya\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in d:\user\chhaya\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in d:\user\chhaya\lib\site-packages (from dtale) (1.15)
# Requirement already satisfied: future>=0.14.0 in d:\user\chhaya\lib\site-packages (from dtale) (1.0.0)
# Requirement already satisfied: kaleido in d:\user\chhaya\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: missingno in d:\user\chhaya\lib\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in d:\user\chhaya\lib\site-packages (from dtale) (2.2.2)
# Requirement already satisfied: squarify in d:\user\chhaya\lib\site-packages (from dtale) (0.4.4)
# Requirement already satisfied: strsimpy in d:\user\chhaya\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in d:\user\chhaya\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in d:\user\chhaya\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in d:\user\chhaya\lib\site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in d:\user\chhaya\lib\site-packages (from dtale) (2024.6.2)
# Requirement already satisfied: flask-ngrok in d:\user\chhaya\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: lz4 in d:\user\chhaya\lib\site-packages (from dtale) (4.3.2)
# Requirement already satisfied: cycler in d:\user\chhaya\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in d:\user\chhaya\lib\site-packages (from dtale) (1.3.1)
# Requirement already satisfied: dash in d:\user\chhaya\lib\site-packages (from dtale) (2.18.1)
# Requirement already satisfied: seaborn in d:\user\chhaya\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: werkzeug in d:\user\chhaya\lib\site-packages (from dtale) (3.0.3)
# Requirement already satisfied: scikit-learn in d:\user\chhaya\lib\site-packages (from dtale) (1.4.2)
# Requirement already satisfied: statsmodels in d:\user\chhaya\lib\site-packages (from dtale) (0.14.2)
# Requirement already satisfied: networkx in d:\user\chhaya\lib\site-packages (from dtale) (3.2.1)
# Requirement already satisfied: numpy in d:\user\chhaya\lib\site-packages (from dtale) (1.26.4)
# Requirement already satisfied: openpyxl!=3.2.0b1 in d:\user\chhaya\lib\site-packages (from dtale) (3.1.2)
# Requirement already satisfied: xarray in d:\user\chhaya\lib\site-packages (from dtale) (2023.6.0)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in d:\user\chhaya\lib\site-packages (from dtale) (1.13.1)
# Requirement already satisfied: et-xmlfile in d:\user\chhaya\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in d:\user\chhaya\lib\site-packages (from dtale) (5.22.0)
# Requirement already satisfied: Flask<2.3 in d:\user\chhaya\lib\site-packages (from dtale) (2.2.5)
# Requirement already satisfied: requests in d:\user\chhaya\lib\site-packages (from dtale) (2.32.2)
# Requirement already satisfied: itsdangerous in d:\user\chhaya\lib\site-packages (from dtale) (2.2.0)
# Requirement already satisfied: contourpy in d:\user\chhaya\lib\site-packages (from dtale) (1.2.0)
# Requirement already satisfied: matplotlib in d:\user\chhaya\lib\site-packages (from dtale) (3.8.4)
# Requirement already satisfied: soupsieve>1.2 in d:\user\chhaya\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\user\chhaya\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\user\chhaya\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in d:\user\chhaya\lib\site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in d:\user\chhaya\lib\site-packages (from dash->dtale) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\user\chhaya\lib\site-packages (from dash->dtale) (4.11.0)
# Requirement already satisfied: retrying in d:\user\chhaya\lib\site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: nest-asyncio in d:\user\chhaya\lib\site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in d:\user\chhaya\lib\site-packages (from dash->dtale) (69.5.1)
# Requirement already satisfied: Jinja2>=3.0 in d:\user\chhaya\lib\site-packages (from Flask<2.3->dtale) (3.1.4)
# Requirement already satisfied: click>=8.0 in d:\user\chhaya\lib\site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in d:\user\chhaya\lib\site-packages (from plotly->dtale) (8.2.2)
# Requirement already satisfied: packaging in d:\user\chhaya\lib\site-packages (from plotly->dtale) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\user\chhaya\lib\site-packages (from werkzeug->dtale) (2.1.3)
# Requirement already satisfied: brotli in d:\user\chhaya\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: zstandard in d:\user\chhaya\lib\site-packages (from Flask-Compress->dtale) (0.22.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\user\chhaya\lib\site-packages (from matplotlib->dtale) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\user\chhaya\lib\site-packages (from matplotlib->dtale) (1.4.4)
# Requirement already satisfied: pillow>=8 in d:\user\chhaya\lib\site-packages (from matplotlib->dtale) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\user\chhaya\lib\site-packages (from matplotlib->dtale) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\user\chhaya\lib\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\user\chhaya\lib\site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\user\chhaya\lib\site-packages (from pandas->dtale) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\user\chhaya\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\user\chhaya\lib\site-packages (from requests->dtale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\user\chhaya\lib\site-packages (from requests->dtale) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\user\chhaya\lib\site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\user\chhaya\lib\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\user\chhaya\lib\site-packages (from statsmodels->dtale) (0.5.6)
# Requirement already satisfied: colorama in d:\user\chhaya\lib\site-packages (from click>=8.0->Flask<2.3->dtale) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in d:\user\chhaya\lib\site-packages (from importlib-metadata->dash->dtale) (3.17.0)
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-DBOB013R:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# building ensemble model
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_train_rf=rf.predict(x_train)
pred_test_rf=rf.predict(x_test)

# %%
# evaluation

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print('*****************Confusion Matrix*****************')
print(confusion_matrix(y_train, pred_train_rf))
print(confusion_matrix(y_test,pred_test_rf))
# Out:
# *****************Confusion Matrix*****************
# [[7548    0    0    0]
#  [   0   93    0    0]
#  [   0    0   16    0]
#  [   0    0    0  444]]
# [[1886    0    0    2]
#  [  22    0    0    1]
#  [   2    0    0    2]
#  [  90    0    0   21]]

# %%
print('*****************classification_report*****************')
print(classification_report(y_train, pred_train_rf))
print(classification_report(y_test,pred_test_rf))
# Out:
# *****************classification_report*****************
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7548
#            1       1.00      1.00      1.00        93
#            2       1.00      1.00      1.00        16
#            3       1.00      1.00      1.00       444
#
#     accuracy                           1.00      8101
#    macro avg       1.00      1.00      1.00      8101
# weighted avg       1.00      1.00      1.00      8101
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1888
#            1       0.00      0.00      0.00        23
#            2       0.00      0.00      0.00         4
#            3       0.81      0.19      0.31       111
#
#     accuracy                           0.94      2026
#    macro avg       0.44      0.30      0.32      2026
# weighted avg       0.92      0.94      0.92      2026

# %%
print('*****************classification_report*****************')
print(accuracy_score(y_train, pred_train_rf))
print(accuracy_score(y_test,pred_test_rf))   # this is good fit
# Out:
# *****************classification_report*****************
# 1.0
# 0.941263573543929

# %% [markdown]
# # Randomforest classifier with feature selection part
# # this is recursive feature technique

# %%
from sklearn.feature_selection import RFE
rf1 = RandomForestClassifier()
feature_1 = RFE(estimator=rf1,n_features_to_select=11,step=1)
feature_1 = feature_1.fit(x_train,y_train)

# %%
pred_train_rf1=feature_1.predict(x_train)
pred_test_rf1=feature_1.predict(x_test)

# %%
print('*****************acurracy_score*****************')
print(accuracy_score(y_train, pred_train_rf1))
print('********************************')
print(accuracy_score(y_test,pred_test_rf1))   # this is good fit
# Out:
# *****************acurracy_score*****************
# 1.0
# ********************************
# 0.9432379072063178

# %%
# cross validation mathod
from sklearn.model_selection import cross_val_score
rf_rfe_training = cross_val_score(feature_1,x_train,y_train,cv=10)
print = (rf_rfe_training)

print = (rf_rfe_training.mean())

# %%
# cross validation method
from sklearn.model_selection import cross_val_score

rf_rfe_training = cross_val_score(feature_1, x_train, y_train, cv=10)

rf_rfe_training  # print the scores
  # this line seems unnecessary, you can remove it
rf_rfe_training.mean()  # print the mean score
# Out:
# 0.9455622535811603

# %% [markdown]
# # PCA method

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca_fit= pca.fit_transform(x_scaled)

# %%
x_train,x_test,y_train,y_test=train_test_split(pca_fit,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_train_gb=gb.predict(x_train)
pred_test_gb=gb.predict(x_test)

# %%
(accuracy_score(y_train, pred_train_gb))
# Out:
# 0.9507468213800765

# %%
(accuracy_score(y_test,pred_test_gb))
# Out:
# 0.9299111549851925
